# %% [markdown]
# ![Ejercicio cangrejos](http://i.gyazo.com/122dd440d65dd45b4ee2853e77d57230.jpg "Ejercicio cangrejos")

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

def lagrange_pol(x_data, y_data):
    x = sp.symbols('x')
    
    P = 0 # Acumulador del polinomio
    n = len(x_data) # Número de datos
    
    for i in range(n):
        Li = 1
        for j in range(n):
            if j != i:
                Li *= (x - x_data[j]) / (x_data[i] - x_data[j])
        P += Li * y_data[i]
    return sp.expand(P)

pez_azul = np.array([14999, 150000, 250000, 275000, 270000, 280000, 290000, 650000, 1200000, 1500000, 2750000])
cangrejo = np.array([99999, 850000, 1330000, 2500000, 3000000, 3700000, 4400000, 4660000, 4800000, 4420000, 5000000])
anios = np.array([1939, 1945, 1950, 1955, 1960, 1965, 1970, 1975, 1980, 1985, 1990])

polinomio_lagrange = lagrange_pol(anios, pez_azul)

plt.plot(anios, pez_azul, 'o', label='Datos')
plt.grid()
plt.xlabel('Años')
plt.ylabel('Pez azul')
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt 

y = np.array([14999, 150000, 250000, 275000, 270000, 280000, 290000, 650000, 1200000, 1500000, 2750000]) #pez azul
cangrejo = np.array([99999, 850000, 1330000, 2500000, 3000000, 3700000, 4400000, 4660000, 4800000, 4420000, 5000000])
x = np.array([1939, 1945, 1950, 1955, 1960, 1965, 1970, 1975, 1980, 1985, 1990]) # Años


plt.figure(figsize=(12, 12), dpi=100)
plt.subplot(331)
plt.plot(x , y, 'or', label='Datos observados') # graficos de dispersión
plt.subplot(332)
plt.plot(x, np.sqrt(y), 'ob')
plt.xlabel('x')
plt.ylabel('$\sqrt{y}$')
plt.subplot(333)
plt.plot(x, 1/y, 'ob')
plt.xlabel('x')
plt.ylabel('$1/y$')
plt.subplot(334)
plt.plot(x**2, y, 'ob')
plt.xlabel('$x^2$')
plt.ylabel('y')
plt.subplot(335)
plt.plot(x**3, y, 'ob')
plt.xlabel('$x^3$')
plt.ylabel('y')
plt.subplot(336)
plt.plot(np.log(x), y, 'ob')
plt.xlabel('$\log(x)$')
plt.ylabel('y')
plt.subplot(337)
plt.plot(x, np.log(y), 'ob')
plt.ylabel('$\log(y)$')
plt.xlabel('x')
plt.subplot(338)
plt.plot(np.sqrt(x), y, 'ob')
plt.xlabel('$\sqrt{x}$')
plt.ylabel('y')
plt.subplot(339)
plt.plot(np.log(x), np.log(y), 'ob')
plt.xlabel('$\log(x)$')
plt.ylabel('$\log(y)$')
# Out:
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# <>:30: SyntaxWarning: invalid escape sequence '\l'
# <>:34: SyntaxWarning: invalid escape sequence '\l'
# <>:38: SyntaxWarning: invalid escape sequence '\s'
# <>:42: SyntaxWarning: invalid escape sequence '\l'
# <>:43: SyntaxWarning: invalid escape sequence '\l'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# <>:30: SyntaxWarning: invalid escape sequence '\l'
# <>:34: SyntaxWarning: invalid escape sequence '\l'
# <>:38: SyntaxWarning: invalid escape sequence '\s'
# <>:42: SyntaxWarning: invalid escape sequence '\l'
# <>:43: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_46718/3889372203.py:15: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel('$\sqrt{y}$')
# /tmp/ipykernel_46718/3889372203.py:30: SyntaxWarning: invalid escape sequence '\l'
#   plt.xlabel('$\log(x)$')
# /tmp/ipykernel_46718/3889372203.py:34: SyntaxWarning: invalid escape sequence '\l'
#   plt.ylabel('$\log(y)$')
# /tmp/ipykernel_46718/3889372203.py:38: SyntaxWarning: invalid escape sequence '\s'
#   plt.xlabel('$\sqrt{x}$')
# /tmp/ipykernel_46718/3889372203.py:42: SyntaxWarning: invalid escape sequence '\l'
#   plt.xlabel('$\log(x)$')
# /tmp/ipykernel_46718/3889372203.py:43: SyntaxWarning: invalid escape sequence '\l'
#   plt.ylabel('$\log(y)$')
# Text(0, 0.5, '$\\log(y)$')
