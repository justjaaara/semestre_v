# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

#paracaidista
vel = [0] # Velocidad inicial del paracaidista
c = 15 # Coeficiente de resistencia 
gravedad = 9.8 # Gravedad
masa = 68.1 # Masa de la persona
h = 0.1 # 6 segundos (intervalo)
t_inicial = 0 # Tiempo inicial
t_final = 120 # 12 Minutos 
# Para calcular los tiempos de la analítica

tiempos = np.arange(t_inicial,t_final+h)
velocidad_analitica = lambda t: ((gravedad * masa)/c)*(1-np.exp((-c/masa)*t))
print(velocidad_analitica(0))
contador = 0
while (t_inicial < t_final):
    vel.append(h*(gravedad - (c/masa)*(vel[-1])) + vel[-1])
    if(round(vel[contador],2) == round(vel[-1],2)):
        print(f'El tiempo en el que cae es: {t_inicial}')
        print(f'EL paracaidista ya se estrelló contra el piso')
        break
    contador+e
    t_inicial+=h

print(vel)
# Out:
# 0.0
# El tiempo en el que cae es: 21.20000000000003
# EL paracaidista ya se estrelló contra el piso
# ...
